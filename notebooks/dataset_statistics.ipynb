# %%
from __future__ import print_function, division
from nilmtk import DataSet, TimeFrame
import pandas as pd
# Out:
# /usr/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/usr/local/lib/python2.7/dist-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)

# %%
dataset = DataSet('/data/mine/vadeec/merged/ukdale.h5')
# dataset.set_window("2014-01-01", "2014-01-02")

for building in dataset.buildings.values():
    try:
        building.elec.use_alternative_mains()
    except RuntimeError:
        pass
    else:
        print("using alternative mains for", building)
        
elec = dataset.buildings[1].elec
# Out:
# using alternative mains for Building(instance=1, dataset='UK-DALE')
# using alternative mains for Building(instance=2, dataset='UK-DALE')
# using alternative mains for Building(instance=5, dataset='UK-DALE')

# %%
dataset.describe(verbose=True)
# Out:
# Running MeterGroup.correlation_of_sum_of_submeters_with_mains()
# HDFDataStore.load. key='/building1/elec/meter54'
#     TimeFrame(start='None', end='None', empty=False)
# n_chunks
#  1
# /home/jack/workspace/python/nilmtk/nilmtk/elecmeter.py:104: UserWarning: There is no meter upstream of this meter 'ElecMeterID(instance=54, building=1, dataset='UK-DALE')' because it is a site meter.
#   .format(self.identifier))
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter38'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter20'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter42'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter24'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter7'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter44'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter11'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter48'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter31'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter13'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter35'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter17'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter37'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter41'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter6'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter10'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter30'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter12'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter34'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter25'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter45'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter49'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter38'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter20'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter42'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter24'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter7'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter44'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter11'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter48'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter31'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter13'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter35'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter17'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter37'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter41'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter6'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter10'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter30'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter12'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter34'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter25'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter45'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter49'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter38'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter20'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter42'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter24'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter7'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter44'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter11'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter48'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter31'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter13'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter35'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter17'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter37'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter41'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter6'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter10'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter30'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter12'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter34'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter25'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter45'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter49'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter38'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter20'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter42'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter24'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter7'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter44'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter11'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter48'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter31'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter13'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter35'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter17'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter37'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter41'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter6'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter10'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter30'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter12'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter34'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter25'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter45'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter49'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter38'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter20'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter42'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter24'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter7'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter44'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter11'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter48'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter31'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter13'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter35'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter17'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter37'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter41'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter6'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter10'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter30'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter12'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter34'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter25'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter45'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter49'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter38'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter20'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter42'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter24'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter7'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter44'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter11'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter48'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter31'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter13'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter35'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter17'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter37'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter41'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter6'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter10'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter30'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter12'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter34'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter25'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter45'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter49'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
# ...
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter25'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter45'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter49'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter14'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter18'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter38'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter20'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter42'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter24'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter7'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter44'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter11'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter48'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter31'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter13'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter35'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter17'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter37'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter41'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter6'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter10'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter30'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter12'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter34'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter16'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter36'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter3'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter40'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter23'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter5'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter27'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter9'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter47'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter29'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter51'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter33'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter53'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter2'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter22'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter4'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter26'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter46'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter28'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter50'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter32'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter15'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter52'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter19'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter39'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter21'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# n_chunks 1
# HDFDataStore.load. key='/building1/elec/meter43'
#     TimeFrame(start='2012-11-09 22:28:18+00:00', end='2014-11-16 06:24:09+00:00', empty=False)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-92083ca3b477> in <module>()
# ----> 1 dataset.describe(verbose=True)
#
# /home/jack/workspace/python/nilmtk/nilmtk/dataset.pyc in describe(self, **kwargs)
#      89         results = pd.DataFrame(columns=keys)
#      90         for i, building in self.buildings.iteritems():
# ---> 91             results[i] = building.describe(**kwargs)
#      92         return results
#
# /home/jack/workspace/python/nilmtk/nilmtk/building.pyc in describe(self, **kwargs)
#      52             series[key] = md.get(key)
#      53
# ---> 54         series = pd.concat([series, self.elec.describe(**kwargs)])
#      55
#      56         return series
#
# /home/jack/workspace/python/nilmtk/nilmtk/metergroup.pyc in describe(self, compute_expensive_stats, **kwargs)
#    1279
#    1280 def iterate_through_submeters_of_two_metergroups(master, slave):
# -> 1281     """
#    1282     Parameters
#    1283     ----------
#
# /home/jack/workspace/python/nilmtk/nilmtk/metergroup.pyc in correlation_of_sum_of_submeters_with_mains(self, **load_kwargs)
#    1267         series = pd.Series()
#    1268
# -> 1269         all_meters = self.meters + self.disabled_meters
#    1270         series['total_n_meters'] = len(all_meters)
#    1271         site_meters = [m for m in all_meters if m.is_site_meter()]
#
# /home/jack/workspace/python/nilmtk/nilmtk/electric.pyc in correlation(self, other, **load_kwargs)
#     269
#     270         x_n, x_sum = sum_and_count(self)
# --> 271         if x_n <= 1:
#     272             return np.NaN
#     273
#
# /home/jack/workspace/python/nilmtk/nilmtk/electric.pyc in sum_and_count(electric)
#     260         load_kwargs.setdefault('sample_period', sample_period)
#     261
# --> 262         def sum_and_count(electric):
#     263             n = 0.0
#     264             cumulator = 0.0
#
# /home/jack/workspace/python/nilmtk/nilmtk/electric.pyc in load_series(self, **kwargs)
#     505         of the ac_types with '+' in between.  e.g. 'active+apparent'.
#     506         """
# --> 507         # Pull data through preprocessing pipeline
#     508         physical_quantity = kwargs['physical_quantity']
#     509         generator = self.load(**kwargs)
#
# /home/jack/workspace/python/nilmtk/nilmtk/metergroup.pyc in load(self, **kwargs)
#     595         _, generators = self._meter_generators(**kwargs)
#     596         while True:
# --> 597             chunk = combine_chunks_from_generators(generators)
#     598             if chunk.empty:
#     599                 break
#
# /home/jack/workspace/python/nilmtk/nilmtk/metergroup.pyc in combine_chunks_from_generators(generators)
#    1337     timeframe = getattr(chunk_store.root._v_attrs, 'timeframe', None)
#    1338     chunk_store.close()
# -> 1339     # TODO : delete file from disk
#    1340
#    1341     # Create mean values by dividing any columns which need dividing
#
# /usr/lib/python2.7/multiprocessing/process.pyc in join(self, timeout)
#     143         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     144         assert self._popen is not None, 'can only join a started process'
# --> 145         res = self._popen.wait(timeout)
#     146         if res is not None:
#     147             _current_process._children.discard(self)
#
# /usr/lib/python2.7/multiprocessing/forking.pyc in wait(self, timeout)
#     152         def wait(self, timeout=None):
#     153             if timeout is None:
# --> 154                 return self.poll(0)
#     155             deadline = time.time() + timeout
#     156             delay = 0.0005
#
# /usr/lib/python2.7/multiprocessing/forking.pyc in poll(self, flag)
#     133                 while True:
#     134                     try:
# --> 135                         pid, sts = os.waitpid(self.pid, flag)
#     136                     except os.error as e:
#     137                         if e.errno == errno.EINTR:
#
# KeyboardInterrupt:

# %%
# elec.meters_directly_downstream_of_mains().total_energy(verbose=True)
# %load_ext memory_profiler

# %%
# %memit elec.power_series(verbose=True, chunksize=2**10).next()

# %% [markdown]
# ```
# with hard-coded section_starT_i and end_i and this call:
# %memit elec.power_series(verbose=True, chunksize=10).next():
# peak memory: 148.93 MiB, increment: 17.11 MiB
#
# with select_as_coordinates:
# peak memory: 305.98 MiB, increment: 190.30 MiB
#
# chunksize = 2**10
# with select_as_coordinates:
# peak memory: 771.50 MiB, increment: 622.86 MiB
#
# with hard-coded:
# peak memory: 643.05 MiB, increment: 527.22 MiB
# ```

# %%
# %memit df = elec[3].power_series(verbose=True, chunksize=2**20).next()
