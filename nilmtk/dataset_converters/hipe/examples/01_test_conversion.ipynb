# %% [markdown]
# ## Test the data conversion

# %% [markdown]
# This corresponds to the official NILMTK guide [here](https://github.com/nilmtk/nilmtk/blob/master/docs/manual/user_guide/data.ipynb). We try to load the data and just see whether the conversion looks right. To convert the data into the HDF-format look at the [README](../README.md).

# %%
from nilmtk import DataSet
from nilmtk.utils import print_dict

hipe = DataSet('../test_1week.hdf')

# %%
print_dict(hipe.metadata)
# Out:
# <ul><li><strong>name</strong>: HIPE</li><li><strong>long_name</strong>: An Energy-Status-Data Set from Industrial Production</li><li><strong>creators</strong>: <ul><li>Bischof, Simon</li><li>Trittenbach, Holger</li><li>Vollmer, Michael</li><li>Werle, Dominik</li><li>Blank, Thomas</li><li>Boehm, Klemens</li></ul></li><li><strong>publication_date</strong>: 2018</li><li><strong>institution</strong>: Karlsruhe Institute of Technology (KIT)</li><li><strong>contact</strong>: firstname.lastname@kit.edu</li><li><strong>description</strong>: High-resolution Industrial Production Energy data set</li><li><strong>subject</strong>: None</li><li><strong>number_of_buildings</strong>: 1</li><li><strong>timezone</strong>: Europe/Berlin</li><li><strong>geo_location</strong>: <ul><li><strong>locality</strong>: Karlsruhe</li><li><strong>country</strong>: DE</li><li><strong>latitude</strong>: 49.099398</li><li><strong>longitude</strong>: 8.433545</li></ul></li><li><strong>related_documents</strong>: <ul>
# ...

# %%
print_dict(hipe.buildings)
# Out:
# <ul><li><strong>1</strong>: Building(instance=1, dataset='HIPE')</li></ul>

# %%
print_dict(hipe.buildings[1].metadata)
# Out:
# <ul><li><strong>instance</strong>: 1</li><li><strong>original_name</strong>: factory_1</li><li><strong>dataset</strong>: HIPE</li></ul>

# %%
hipe.buildings[1].elec.draw_wiring_graph()
# Out:
# (<networkx.classes.digraph.DiGraph at 0x7fc299d96970>,
#  <matplotlib.axes._axes.Axes at 0x7fc299d43ac0>)
